# %%
#Libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
link = 'https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv'

data = pd.read_csv(link)
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.shape
# Out:
# (25, 2)

# %% [markdown]
# We can see we have only 2 columns and we want to predict Scores from hours

# %%
plt.title('Scores vs hours')
sns.scatterplot(data=data, x = 'Hours', y = 'Scores')
plt.show();

# %%
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

print('Sucessfully converted columns to array')
# Out:
# Sucessfully converted columns to array

# %% [markdown]
# ##Spliting Train and Test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# ##Training

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train,y_train)

print('training complete')
# Out:
# training complete

# %% [markdown]
# ##Vizualizing

# %%
line = lr.coef_*X+lr.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.show()

# %% [markdown]
# ##Predicting

# %%
print(X_test) # Testing data - In Hours
y_pred = lr.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# ##Score

# %%
from sklearn import metrics
print(f'MSE: {metrics.mean_absolute_error(y_pred, y_test)}')
# Out:
# MSE: 4.183859899002982

# %% [markdown]
# ##New Prediction

# %%
import warnings 
warnings.filterwarnings('ignore')

new_value = [['9.25']]

# %%
print(f'The Student Will get : {lr.predict(new_value)}. if he study {new_value} hours per day')
# Out:
# The Student Will get : [93.69173249]. if he study [['9.25']] hours per day
